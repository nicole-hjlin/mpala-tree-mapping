# %%
import gdown

# # a file
# url = "https://drive.google.com/uc?id=1l_5RK28JRL19wpT22B-DY9We3TVXnnQQ"
# output = "fcn8s_from_caffe.npz"
# gdown.download(url, output, quiet=False)

# same as the above, but with the file ID
id = "1towBoLILyYrewrU8Lax6s3VaRZJIdyB0"
gdown.download_folder(id=id, quiet=False, remaining_ok=True)

# # same as the above, and you can copy-and-paste a URL from Google Drive with fuzzy=True
# url = "https://drive.google.com/file/d/0B9P1L--7Wd2vNm9zMTJWOGxobkU/view?usp=sharing"
# gdown.download(url=url, output=output, quiet=False, fuzzy=True)

# # cached download with identity check via MD5
# md5 = "fa837a88f0c40c513d975104edf3da17"
# gdown.cached_download(url, output, md5=md5, postprocess=gdown.extractall)

# # a folder
# url = "https://drive.google.com/drive/folders/15uNXeRBIhVvZJIhL4yTw4IsStMhUaaxl"
# gdown.download_folder(url, quiet=True, use_cookies=False)

# # same as the above, but with the folder ID
# id = "15uNXeRBIhVvZJIhL4yTw4IsStMhUaaxl"
# gdown.download_folder(id=id, quiet=True, use_cookies=False)
# Out:
# Retrieving folder list
# Processing file 15kLE23MgCC0xT28T9gKwJdddWU2PJYnO treeID_1.las
# Processing file 1JcJb8QX6fTmoT3rQr3cHPe5MUtlR5QN_ treeID_2.las
# Processing file 1-0MDAO_Py3QPAH7ALHWKJPsGPK8eyLRS treeID_3.las
# Processing file 1VRk0kXxKrid77giRK8PL8YYzBSVIUIzJ treeID_4.las
# Processing file 1pLtQfwY8GXtevxdrKnD3KL-We9LVnqdR treeID_5.las
# Processing file 1kvvqw93SC45lqEcKhOrUOO85b4RkKDy_ treeID_6.las
# Processing file 1m0urUr2CIBklobjhHPI3cKVl6N2k46M- treeID_7.las
# Processing file 1kSR2RP77ltQ_O5XOOMaCquhqaoQptlbe treeID_8.las
# Processing file 1JAjOyvWQSg8rtY4nCtM_gEIjcCFe2cXm treeID_9.las
# Processing file 12331qd0scRcaiR2u1JhRdh9Kpj3YztNi treeID_10.las
# Processing file 1qGye-m7vHPzPphaSdG0Kirw1X4GiLdAH treeID_11.las
# Processing file 1WcnzhSYDpmsmtwbkeEk55-eoGbMPD3zF treeID_12.las
# Processing file 1oTSlmkAuD2ACijrJn1lVkHcYS28dAHc9 treeID_13.las
# Processing file 1KC9-2jrTwQBsNEuVio6Ewsz7dugTzNRi treeID_14.las
# Processing file 1TmD4T1MGGDLOY8EIoSf3vx8KuoxFKcCA treeID_15.las
# Processing file 1-kEd6QsgBZmnujhj71xSTf5zhOlFBC0b treeID_16.las
# Processing file 1I_p1i5nSNpXBWW8qwkl6CHffnETGadLK treeID_17.las
# Processing file 12QDbYRtiAdJSSmmM6teZekxH22jw575q treeID_18.las
# Processing file 1sv5KBtyxNgUkglxrXqC6nNCDjKjxfQLu treeID_19.las
# Processing file 1kt81aVQd0ucy9KXQfMnDkqBnbmCeLhrB treeID_20.las
# Processing file 16Y_6MwRXI_wQ5T0gXtUwZD_of-D9zROf treeID_21.las
# Processing file 1uYAQKLKaBzHL9XJo6EFcUare4GdXO5mf treeID_22.las
# Processing file 1UXO1yYbkc3agMb51JLTEAd14u8DOdwpl treeID_23.las
# Processing file 1vpMpIUzE_D7n-9rtdd-ZXcDlpX5v4uxt treeID_24.las
# Processing file 1a8SGTRMfVMYH3S7q5rWF5B9YPTfjX1Fd treeID_25.las
# To: /Users/matthew/mpala-tree-mapping/MpalaForestGEO_LasClippedtoTreePolygons/treeID_31.las
# 100%|██████████| 2.83k/2.83k [00:00<00:00, 9.56MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1RazcvbEY6CuqiifdjA20Z3ed2MMWtptS
# To: /Users/matthew/mpala-tree-mapping/MpalaForestGEO_LasClippedtoTreePolygons/treeID_32.las
# 100%|██████████| 1.08k/1.08k [00:00<00:00, 3.79MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1jTJm4skL0HoJ7ZR5aXGzhMN3KBZGuTil
# To: /Users/matthew/mpala-tree-mapping/MpalaForestGEO_LasClippedtoTreePolygons/treeID_33.las
# 100%|██████████| 701/701 [00:00<00:00, 1.46MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1FGZ3dZ1A2f2zB4gaOJ6aNfvt_KHIfIVy
# To: /Users/matthew/mpala-tree-mapping/MpalaForestGEO_LasClippedtoTreePolygons/treeID_34.las
# 100%|██████████| 663/663 [00:00<00:00, 2.71MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1dAuVC0kNPpzvnBDirqB6M542sDnWqOFY
# To: /Users/matthew/mpala-tree-mapping/MpalaForestGEO_LasClippedtoTreePolygons/treeID_35.las
# 100%|██████████| 1.50k/1.50k [00:00<00:00, 10.1MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1cBF_caFj6ZBhZbtpcbpGuHH62jgnKQPZ
# To: /Users/matthew/mpala-tree-mapping/MpalaForestGEO_LasClippedtoTreePolygons/treeID_36.las
# 100%|██████████| 1.04k/1.04k [00:00<00:00, 3.09MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1Z02WmxIiOZkEYUX5yR_d8LWgFdCBs54B
# To: /Users/matthew/mpala-tree-mapping/MpalaForestGEO_LasClippedtoTreePolygons/treeID_37.las
# 100%|██████████| 549/549 [00:00<00:00, 1.81MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1ydql6OH19FTftNk9fOnacDgCJXP5EnKM
# To: /Users/matthew/mpala-tree-mapping/MpalaForestGEO_LasClippedtoTreePolygons/treeID_38.las
# 100%|██████████| 3.67k/3.67k [00:00<00:00, 24.6MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1LXrSZn3vH4CSWYeJQSLnkZONsfZErKFv
# To: /Users/matthew/mpala-tree-mapping/MpalaForestGEO_LasClippedtoTreePolygons/treeID_39.las
# 100%|██████████| 1.46k/1.46k [00:00<00:00, 6.73MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1lWXQ5jxJj-aQecTm9wlFY5Q0zyCzJJGY
# To: /Users/matthew/mpala-tree-mapping/MpalaForestGEO_LasClippedtoTreePolygons/treeID_40.las
# 100%|██████████| 1.04k/1.04k [00:00<00:00, 4.21MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1TlnMNZlj7VHgwIRS3SVjTD4JE1p6ztxo
# To: /Users/matthew/mpala-tree-mapping/MpalaForestGEO_LasClippedtoTreePolygons/treeID_41.las
# 100%|██████████| 1.69k/1.69k [00:00<00:00, 5.12MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1rtE2tvKwkvk-l-3SgQeHi-irDFGjfcit
# To: /Users/matthew/mpala-tree-mapping/MpalaForestGEO_LasClippedtoTreePolygons/treeID_42.las
# 100%|██████████| 6.13k/6.13k [00:00<00:00, 14.0kB/s]
# Downloading...
# From: https://drive.google.com/uc?id=19r4H70s02yq_yETG6ZBPLv3SDmdSsgmG
# To: /Users/matthew/mpala-tree-mapping/MpalaForestGEO_LasClippedtoTreePolygons/treeID_43.las
# 100%|██████████| 1.96k/1.96k [00:00<00:00, 15.1MB/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [6], line 10
#       3 # # a file
#       4 # url = "https://drive.google.com/uc?id=1l_5RK28JRL19wpT22B-DY9We3TVXnnQQ"
#       5 # output = "fcn8s_from_caffe.npz"
#       6 # gdown.download(url, output, quiet=False)
#       7
#       8 # same as the above, but with the file ID
#       9 id = "1towBoLILyYrewrU8Lax6s3VaRZJIdyB0"
# ---> 10 gdown.download_folder(id=id, quiet=False, remaining_ok=True)
#      12 # # same as the above, and you can copy-and-paste a URL from Google Drive with fuzzy=True
#      13 # url = "https://drive.google.com/file/d/0B9P1L--7Wd2vNm9zMTJWOGxobkU/view?usp=sharing"
#      14 # gdown.download(url=url, output=output, quiet=False, fuzzy=True)
#    (...)
#      25 # id = "15uNXeRBIhVvZJIhL4yTw4IsStMhUaaxl"
#      26 # gdown.download_folder(id=id, quiet=True, use_cookies=False)
#
# File ~/mpala-tree-mapping/venv/lib/python3.10/site-packages/gdown/download_folder.py:353, in download_folder(url, id, output, quiet, proxy, speed, use_cookies, remaining_ok)
#     350         os.makedirs(file_path)
#     351     continue
# --> 353 filename = download(
#     354     files_url + file_id,
#     355     output=file_path,
#     356     quiet=quiet,
#     357     proxy=proxy,
#     358     speed=speed,
#     359     use_cookies=use_cookies,
#     360 )
#     362 if filename is None:
#     363     if not quiet:
#
# File ~/mpala-tree-mapping/venv/lib/python3.10/site-packages/gdown/download.py:146, in download(url, output, quiet, proxy, speed, use_cookies, verify, id, fuzzy, resume)
#     144 while True:
#     145     try:
# --> 146         res = sess.get(url, headers=headers, stream=True, verify=verify)
#     147     except requests.exceptions.ProxyError as e:
#     148         print("An error has occurred using proxy:", proxy, file=sys.stderr)
#
# File ~/mpala-tree-mapping/venv/lib/python3.10/site-packages/requests/sessions.py:600, in Session.get(self, url, **kwargs)
#     592 r"""Sends a GET request. Returns :class:`Response` object.
#     593
#     594 :param url: URL for the new :class:`Request` object.
#     595 :param \*\*kwargs: Optional arguments that ``request`` takes.
#     596 :rtype: requests.Response
#     597 """
#     599 kwargs.setdefault("allow_redirects", True)
# --> 600 return self.request("GET", url, **kwargs)
#
# File ~/mpala-tree-mapping/venv/lib/python3.10/site-packages/requests/sessions.py:587, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     582 send_kwargs = {
#     583     "timeout": timeout,
#     584     "allow_redirects": allow_redirects,
#     585 }
#     586 send_kwargs.update(settings)
# --> 587 resp = self.send(prep, **send_kwargs)
#     589 return resp
#
# File ~/mpala-tree-mapping/venv/lib/python3.10/site-packages/requests/sessions.py:723, in Session.send(self, request, **kwargs)
#     720 if allow_redirects:
#     721     # Redirect resolving generator.
#     722     gen = self.resolve_redirects(r, request, **kwargs)
# --> 723     history = [resp for resp in gen]
#     724 else:
#     725     history = []
#
# File ~/mpala-tree-mapping/venv/lib/python3.10/site-packages/requests/sessions.py:723, in <listcomp>(.0)
#     720 if allow_redirects:
#     721     # Redirect resolving generator.
#     722     gen = self.resolve_redirects(r, request, **kwargs)
# --> 723     history = [resp for resp in gen]
#     724 else:
#     725     history = []
#
# File ~/mpala-tree-mapping/venv/lib/python3.10/site-packages/requests/sessions.py:266, in SessionRedirectMixin.resolve_redirects(self, resp, req, stream, timeout, verify, cert, proxies, yield_requests, **adapter_kwargs)
#     263     yield req
#     264 else:
# --> 266     resp = self.send(
#     267         req,
#     268         stream=stream,
#     269         timeout=timeout,
#     270         verify=verify,
#     271         cert=cert,
#     272         proxies=proxies,
#     273         allow_redirects=False,
#     274         **adapter_kwargs,
#     275     )
#     277     extract_cookies_to_jar(self.cookies, prepared_request, resp.raw)
#     279     # extract redirect url, if any, for the next loop
#
# File ~/mpala-tree-mapping/venv/lib/python3.10/site-packages/requests/sessions.py:701, in Session.send(self, request, **kwargs)
#     698 start = preferred_clock()
#     700 # Send the request
# --> 701 r = adapter.send(request, **kwargs)
#     703 # Total elapsed time of the request (approximately)
#     704 elapsed = preferred_clock() - start
#
# File ~/mpala-tree-mapping/venv/lib/python3.10/site-packages/requests/adapters.py:489, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     487 try:
#     488     if not chunked:
# --> 489         resp = conn.urlopen(
#     490             method=request.method,
#     491             url=url,
#     492             body=request.body,
#     493             headers=request.headers,
#     494             redirect=False,
#     495             assert_same_host=False,
#     496             preload_content=False,
#     497             decode_content=False,
#     498             retries=self.max_retries,
#     499             timeout=timeout,
#     500         )
#     502     # Send the request.
#     503     else:
#     504         if hasattr(conn, "proxy_pool"):
#
# File ~/mpala-tree-mapping/venv/lib/python3.10/site-packages/urllib3/connectionpool.py:703, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     700     self._prepare_proxy(conn)
#     702 # Make the request on the httplib connection object.
# --> 703 httplib_response = self._make_request(
#     704     conn,
#     705     method,
#     706     url,
#     707     timeout=timeout_obj,
#     708     body=body,
#     709     headers=headers,
#     710     chunked=chunked,
#     711 )
#     713 # If we're going to release the connection in ``finally:``, then
#     714 # the response doesn't need to know about the connection. Otherwise
#     715 # it will also try to release it and we'll have a double-release
#     716 # mess.
#     717 response_conn = conn if not release_conn else None
#
# File ~/mpala-tree-mapping/venv/lib/python3.10/site-packages/urllib3/connectionpool.py:449, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     444             httplib_response = conn.getresponse()
#     445         except BaseException as e:
#     446             # Remove the TypeError from the exception chain in
#     447             # Python 3 (including for exceptions like SystemExit).
#     448             # Otherwise it looks like a bug in the code.
# --> 449             six.raise_from(e, None)
#     450 except (SocketTimeout, BaseSSLError, SocketError) as e:
#     451     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File <string>:3, in raise_from(value, from_value)
#
# File ~/mpala-tree-mapping/venv/lib/python3.10/site-packages/urllib3/connectionpool.py:444, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     441 except TypeError:
#     442     # Python 3
#     443     try:
# --> 444         httplib_response = conn.getresponse()
#     445     except BaseException as e:
#     446         # Remove the TypeError from the exception chain in
#     447         # Python 3 (including for exceptions like SystemExit).
#     448         # Otherwise it looks like a bug in the code.
#     449         six.raise_from(e, None)
#
# File /opt/homebrew/Cellar/python@3.10/3.10.8/Frameworks/Python.framework/Versions/3.10/lib/python3.10/http/client.py:1374, in HTTPConnection.getresponse(self)
#    1372 try:
#    1373     try:
# -> 1374         response.begin()
#    1375     except ConnectionError:
#    1376         self.close()
#
# File /opt/homebrew/Cellar/python@3.10/3.10.8/Frameworks/Python.framework/Versions/3.10/lib/python3.10/http/client.py:318, in HTTPResponse.begin(self)
#     316 # read until we get a non-100 response
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#     320         break
#
# File /opt/homebrew/Cellar/python@3.10/3.10.8/Frameworks/Python.framework/Versions/3.10/lib/python3.10/http/client.py:279, in HTTPResponse._read_status(self)
#     278 def _read_status(self):
# --> 279     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280     if len(line) > _MAXLINE:
#     281         raise LineTooLong("status line")
#
# File /opt/homebrew/Cellar/python@3.10/3.10.8/Frameworks/Python.framework/Versions/3.10/lib/python3.10/socket.py:705, in SocketIO.readinto(self, b)
#     703 while True:
#     704     try:
# --> 705         return self._sock.recv_into(b)
#     706     except timeout:
#     707         self._timeout_occurred = True
#
# File /opt/homebrew/Cellar/python@3.10/3.10.8/Frameworks/Python.framework/Versions/3.10/lib/python3.10/ssl.py:1274, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1270     if flags != 0:
#    1271         raise ValueError(
#    1272           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1273           self.__class__)
# -> 1274     return self.read(nbytes, buffer)
#    1275 else:
#    1276     return super().recv_into(buffer, nbytes, flags)
#
# File /opt/homebrew/Cellar/python@3.10/3.10.8/Frameworks/Python.framework/Versions/3.10/lib/python3.10/ssl.py:1130, in SSLSocket.read(self, len, buffer)
#    1128 try:
#    1129     if buffer is not None:
# -> 1130         return self._sslobj.read(len, buffer)
#    1131     else:
#    1132         return self._sslobj.read(len)
#
# KeyboardInterrupt:
